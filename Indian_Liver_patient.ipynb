# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/drive/MyDrive/Datasets/Indian Liver Patient Dataset (ILPD).csv')

# %%
df.columns=df.columns.str.capitalize()

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Tot_bilirubin', 'Direct_bilirubin', 'Tot_proteins',
#        'Albumin', 'Ag_ratio', 'Sgpt', 'Sgot', 'Alkphos', 'Is_patient'],
#       dtype='object')

# %%
df.head()
# Out:
#    Age  Gender  Tot_bilirubin  Direct_bilirubin  Tot_proteins  Albumin  \
# 0   65  Female            0.7               0.1           187       16
# 1   62    Male           10.9               5.5           699       64
# 2   62    Male            7.3               4.1           490       60
# 3   58    Male            1.0               0.4           182       14
# 4   72    Male            3.9               2.0           195       27
#
#    Ag_ratio  Sgpt  Sgot  Alkphos  Is_patient
# 0        18   6.8   3.3     0.90           1
# 1       100   7.5   3.2     0.74           1
# 2        68   7.0   3.3     0.89           1
# 3        20   6.8   3.4     1.00           1
# 4        59   7.3   2.4     0.40           1

# %%
df.describe()
# Out:
#               Age  Tot_bilirubin  Direct_bilirubin  Tot_proteins      Albumin  \
# count  583.000000     583.000000        583.000000    583.000000   583.000000
# mean    44.746141       3.298799          1.486106    290.576329    80.713551
# std     16.189833       6.209522          2.808498    242.937989   182.620356
# min      4.000000       0.400000          0.100000     63.000000    10.000000
# 25%     33.000000       0.800000          0.200000    175.500000    23.000000
# 50%     45.000000       1.000000          0.300000    208.000000    35.000000
# 75%     58.000000       2.600000          1.300000    298.000000    60.500000
# max     90.000000      75.000000         19.700000   2110.000000  2000.000000
#
#           Ag_ratio        Sgpt        Sgot     Alkphos  Is_patient
# count   583.000000  583.000000  583.000000  579.000000  583.000000
# mean    109.910806    6.483190    3.141852    0.947064    1.286449
# ...

# %%
df.isnull().sum()
# Out:
# Age                 0
# Gender              0
# Tot_bilirubin       0
# Direct_bilirubin    0
# Tot_proteins        0
# Albumin             0
# Ag_ratio            0
# Sgpt                0
# Sgot                0
# Alkphos             4
# Is_patient          0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#      Age  Gender  Tot_bilirubin  Direct_bilirubin  Tot_proteins  Albumin  \
# 0     65  Female            0.7               0.1           187       16
# 1     62    Male           10.9               5.5           699       64
# 2     62    Male            7.3               4.1           490       60
# 3     58    Male            1.0               0.4           182       14
# 4     72    Male            3.9               2.0           195       27
# ..   ...     ...            ...               ...           ...      ...
# 578   60    Male            0.5               0.1           500       20
# 579   40    Male            0.6               0.1            98       35
# 580   52    Male            0.8               0.2           245       48
# 581   31    Male            1.3               0.5           184       29
# 582   38    Male            1.0               0.3           216       21
#
#      Ag_ratio  Sgpt  Sgot  Alkphos  Is_patient
# ...

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      439
# Female    140
# Name: count, dtype: int64

# %%
df['Is_patient'].value_counts()
# Out:
# Is_patient
# 1    414
# 2    165
# Name: count, dtype: int64

# %%
df.query('Age < 10').value_counts()
# Out:
# Age  Gender  Tot_bilirubin  Direct_bilirubin  Tot_proteins  Albumin  Ag_ratio  Sgpt  Sgot  Alkphos  Is_patient
# 4    Male    0.8            0.2               460           152      231       6.5   3.2   0.9      2             1
#              0.9            0.2               348           30       34        8.0   4.0   1.0      2             1
# 6    Male    0.6            0.1               289           38       30        4.8   2.0   0.7      2             1
# 7    Female  27.2           11.8              1420          790      1050      6.1   2.0   0.4      1             1
#      Male    0.5            0.1               352           28       51        7.9   4.2   1.1      2             1
# 8    Female  0.9            0.2               401           25       58        7.5   3.4   0.8      1             1
# Name: count, dtype: int64

# %%
df[['Age','Tot_bilirubin','Direct_bilirubin','Tot_proteins','Albumin','Ag_ratio','Sgpt','Sgot','Alkphos','Is_patient']].corr()
# Out:
#                        Age  Tot_bilirubin  Direct_bilirubin  Tot_proteins  \
# Age               1.000000       0.011000          0.006784      0.078878
# Tot_bilirubin     0.011000       1.000000          0.874481      0.205739
# Direct_bilirubin  0.006784       0.874481          1.000000      0.234008
# Tot_proteins      0.078878       0.205739          0.234008      1.000000
# Albumin          -0.087799       0.213375          0.233180      0.124777
# Ag_ratio         -0.020499       0.237323          0.257022      0.166580
# Sgpt             -0.186248      -0.007906          0.000033     -0.027062
# Sgot             -0.264211      -0.222087         -0.228409     -0.163419
# Alkphos          -0.216408      -0.206267         -0.200125     -0.234166
# Is_patient       -0.133164      -0.220218         -0.246273     -0.183363
#
#                    Albumin  Ag_ratio      Sgpt      Sgot   Alkphos  Is_patient
# ...

# %% [markdown]
# Visualization

# %%
df['Gender'].value_counts().plot(kind='pie') \
            .set_title("Gender Distribution")
plt.ylabel('Count')
plt.show()

# %%
sns.barplot(x=df['Is_patient'],y=df['Age'],hue=df['Gender'])
plt.title('Patients based on Age and gender')
plt.show()

# %%
Cols=df[['Age','Tot_bilirubin','Direct_bilirubin','Tot_proteins','Albumin','Ag_ratio','Sgpt','Sgot','Alkphos','Is_patient']].corr()
sns.heatmap(Cols,cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.boxenplot(x=df['Gender'],y=df['Sgot'])
plt.title('Sgot by Gender')
plt.show()

# %%
sns.displot(x=df['Alkphos'],kind='kde',hue=df['Gender'])

# %%
df.groupby('Age')['Is_patient'].value_counts(sort=True)\
  .tail(5)\
  .plot(kind='bar')
# Out:
# <Axes: xlabel='Age,Is_patient'>

# %%
sns.pairplot(df,vars=['Age','Ag_ratio','Sgpt','Sgot','Alkphos'],hue='Gender')

# %% [markdown]
# # Creation of **Model**

# %%
df['Gender']=df['Gender'].map({'Male':1,'Female':2})

# %%
# independent variables and dependent variable
x=df.drop('Is_patient',axis=1)
y=df['Is_patient']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)

from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression(solver='lbfgs', max_iter=1000)
logreg.fit(X_train,y_train)
y_pred=logreg.predict(X_test)

# %%
from sklearn.ensemble import AdaBoostClassifier
model = AdaBoostClassifier(n_estimators=50, learning_rate=1)
model.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(learning_rate=1)

# %%
df2 = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
print(df2.to_string())
# Out:
#      Actual  Predicted
# 499       1          1
# 403       2          1
# 485       1          1
# 103       2          1
# 122       2          1
# 467       2          1
# 406       2          1
# 34        2          1
# 561       1          1
# 175       1          1
# 202       2          2
# 324       1          1
# 287       2          1
# 214       1          1
# 501       1          1
# 412       1          1
# 75        2          1
# 206       1          1
# 165       1          1
# 190       1          1
# 337       1          1
# 64        1          1
# 462       1          1
# 382       1          1
# 500       1          1
# 556       1          1
# 526       1          1
# 369       1          1
# 242       1          1
# 352       1          2
# 240       2          1
# 196       1          1
# 52        1          1
# 311       1          1
# 236       2          1
# 426       2          1
# 212       2          1
# 288       1          1
# 468       1          1
# ...

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
acc=metrics.accuracy_score(y_test, y_pred)
print(acc*100,'%')
# Out:
# Mean Absolute Error: 0.2827586206896552
# Mean Squared Error: 0.2827586206896552
# Root Mean Squared Error: 0.5317505248607237
# 71.72413793103448 %
